# %%
import tkinter as tk
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.csv')
df1 = pd.read_csv('test.csv') 
x=  df.drop(['Id', 'Open Date', 'City', 'City Group', 'Type',#'_Ankara','_Trabzon','_Tokat','_İstanbul','_Uşak','_İzmir','_Şanlıurfa','_Muğla','_Osmaniye','_Sakarya','_Samsun','_Tekirdağ','_Kayseri','_Kocaeli','_Konya','_Kütahya','_Kırklareli','_Eskişehir','_Gaziantep','_Isparta','_Karabük','_Kastamonu','_Bursa','_Denizli','_Diyarbakır','_Edirne','_Elazığ','_Amasya','_Antalya','_Aydın','_Balıkesir','_Bolu','City_cat','City Group_cat','Type_cat','_Adana','_Afyonkarahisar'], axis=1).values
y = df['revenue']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=1/3, random_state=202)
from sklearn.tree import DecisionTreeRegressor 
reg= DecisionTreeRegressor(max_depth=10)
reg.fit(xtrain, ytrain)
pred = reg.score(xtrain,ytrain)
y_pred = reg.predict(xtest)
final_model = reg
pd.to_pickle(final_model,'Restaurant2')

def Predict():
    model = pd.to_pickle(final_model,'Restaurant2')
    cols = ['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','P17','P18','P19','P20','P21','P22','P23','P24','P25','P26','P27','P28','P29','P30','P31','P32','P33','P34','P35','P36','P37','_Big Cities','_Other','_DT','_IL','_FC']
    query = pd.DataFrame({'_Big Cities':[big.get()],
                     '_Other':[other.get()],
                     '_DT':[DL.get()],
                     '_IL':[IL.get()],
                     '_FC':[FC.get()],
                     'P1':[P1.get()],
                     'P2':[P2.get()],
                     'P3':[P3.get()],
                     'P4':[P4.get()],
                     'P5':[P5.get()],
                     'P6':[P6.get()],
                     'P7':[P7.get()],
                     'P8':[P8.get()],
                     'P9':[P9.get()],
                     'P10':[P10.get()],
                     'P11':[P11.get()],
                     'P12':[P12.get()],
                     'P13':[P13.get()],
                     'P14':[P14.get()],
                     'P15':[P15.get()],
                     'P16':[P16.get()],
                     'P17':[P17.get()],
                     'P18':[P18.get()],
                     'P19':[P19.get()],
                     'P20':[P20.get()],
                     'P21':[P21.get()],
                     'P22':[P22.get()],
                     'P23':[P23.get()],
                     'P24':[P24.get()],
                     'P25':[P25.get()],
                     'P26':[P26.get()],
                     'P27':[P27.get()],
                     'P28':[P28.get()],
                     'P29':[P29.get()],
                     'P30':[P30.get()],
                     'P31':[P31.get()],
                     'P32':[P32.get()],
                     'P33':[P33.get()],
                     'P34':[P34.get()],
                     'P35':[P35.get()],
                     'P36':[P36.get()],
                     'P37':[P37].get()})
    
## Creating GUI

app = tk.Tk()
app.geometry('800x750')
app.title("Restaurant Revenue Prediction")
app.configure(background='#567')

## Lables
tk.Label(app,text='Restaurant Revenue Precdiction Model',font=('georgia', 15 ,"bold"),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter The Big City(0/1)',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter The Other(0/1)',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter DT(0/1)',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter IL(0/1)',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter FC(0/1)',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P1',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P2',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P3',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P4',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P5',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P6',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P7',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P8',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P9',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P10',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P11',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P12',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P13',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P14',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P15',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P16',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P17',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P18',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P19',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P20',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P21',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P22',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P23',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P24',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P25',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P26',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P27',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P28',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P29',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app,text='Enter P30',font=('georgia', 10),bg='black',fg='red').place(x=100,y=10)
tk.Label(app, text='Enter P31',font=('Georgia',10),fg= 'Black').place(x=50,y=50)
tk.Label(app, text='Enter P32',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P33',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P34',font=('Georgia',10),fg='black').place(x=50,y=200)
tk.Label(app, text='Enter P35',font=('Georgia',10),fg='black').place(x=50,y=100)
tk.Label(app, text='Enter P36',font=('Georgia',10),fg='black').place(x=50,y=150)
tk.Label(app, text='Enter P37',font=('Georgia',10),fg='black').place(x=50,y=200)


    


app.mainloop()
# Out:
#   File "<ipython-input-9-5725d36fe6fc>", line 4
#     y = df['revenue']
#       ^
# SyntaxError: invalid syntax
